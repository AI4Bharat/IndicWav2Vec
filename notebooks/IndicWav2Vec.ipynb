# %% [markdown]
# # IndicWav2Vec Tutorial

# %% [markdown]
# ## 1. Quick Demo (using HuggingFace)

# %% [markdown]
# ### Installation and Setup

# %% [markdown]
# Install Ubuntu/Debian Packages -

# %%
! apt-get install build-essential libboost-all-dev cmake zlib1g-dev libbz2-dev liblzma-dev
# Out:
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?

# %% [markdown]
# Install Python Packages -
# 1. [PyTorch](https://pytorch.org/get-started/locally/)
# 2. [torchaudio](https://pytorch.org/get-started/locally/)
# 3. HuggingFace's [Transformers](https://huggingface.co/docs/transformers/installation)
# 4. HuggingFace's [Datasets](https://huggingface.co/docs/datasets/installation)
# 5. Kensho's [pyctcdecode](https://github.com/kensho-technologies/pyctcdecode)
# 6. [Kenlm's](https://github.com/kpu/kenlm) Python Bindings
#
# For detailed instruction, please follow the above links to their respective documentation pages.

# %%
! pip install torch torchaudio transformers datasets pyctcdecode
! pip install https://github.com/kpu/kenlm/archive/master.zip
# Out:
# Requirement already satisfied: torch in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (1.12.0)
# Requirement already satisfied: torchaudio in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (0.12.0)
# Requirement already satisfied: transformers in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (4.20.1)
# Requirement already satisfied: datasets in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (2.4.0)
# Requirement already satisfied: typing-extensions in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from torch) (4.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: numpy>=1.17 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from transformers) (1.23.1)
# Requirement already satisfied: packaging>=20.0 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from transformers) (4.64.0)
# Requirement already satisfied: filelock in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from transformers) (3.7.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from transformers) (0.12.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from transformers) (0.8.1)
# Requirement already satisfied: pandas in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from datasets) (1.2.2)
# Requirement already satisfied: xxhash in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from datasets) (3.0.0)
# Requirement already satisfied: multiprocess in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from datasets) (0.70.13)
# Requirement already satisfied: pyarrow>=6.0.0 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from datasets) (8.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from datasets) (2022.5.0)
# Requirement already satisfied: aiohttp in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from datasets) (3.8.1)
# Requirement already satisfied: responses<0.19 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: dill<0.3.6 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from requests->transformers) (1.26.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: pytz>=2017.3 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/speech/tools_setup/miniconda3/envs/kenlm/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.16.0)

# %% [markdown]
# Import Packages -

# %%
# Import statements (for libraries: transformers, torchaudio and torch)
from transformers import AutoModelForCTC, AutoProcessor
import torchaudio
import torch
# Enable audio on jupyter notebooks
from IPython.display import Audio, display

# Optional (import datasets)
from datasets import load_dataset

# %% [markdown]
# ### [Appendix A] Helper Functions

# %%
def load_audio_from_file(file_path):
    waveform, sample_rate = torchaudio.load(file_path)
    num_channels, _ = waveform.shape
    if num_channels == 1:
        return waveform[0], sample_rate
    else:
        raise ValueError("Waveform with more than 1 channels are not supported.")

# %% [markdown]
# #### Insight: Why HuggingFace?

# %% [markdown]
# ### Data Preparation: Load Samples

# %% [markdown]
# Download Sample

# %%
! mkdir ../samples
! wget https://t3638486.p.clickup-attachments.com/t3638486/280ccfa7-bf22-4d3e-9c6d-de22e3c3c467/common_voice_hi_32806346.mp3 && mv common_voice_hi_32806346.mp3 ../samples/
# Out:
# mkdir: cannot create directory ‘../samples’: File exists
# --2022-07-27 01:05:32--  https://t3638486.p.clickup-attachments.com/t3638486/280ccfa7-bf22-4d3e-9c6d-de22e3c3c467/common_voice_hi_32806346.mp3
# Resolving t3638486.p.clickup-attachments.com (t3638486.p.clickup-attachments.com)... 13.35.191.18, 13.35.191.100, 13.35.191.83, ...
# Connecting to t3638486.p.clickup-attachments.com (t3638486.p.clickup-attachments.com)|13.35.191.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23373 (23K) [application/octet-stream]
# Saving to: ‘common_voice_hi_32806346.mp3’
#
# common_voice_hi_328 100%[===================>]  22.83K  --.-KB/s    in 0s
#
# 2022-07-27 01:05:32 (99.8 MB/s) - ‘common_voice_hi_32806346.mp3’ saved [23373/23373]

# %% [markdown]
# Load the Sample in PyTorch

# %%
SAMPLE_AUDIO_PATH = "../samples/common_voice_hi_32806346.mp3"
TARGET_SAMPLE_RATE = 16000

waveform, sample_rate = load_audio_from_file(SAMPLE_AUDIO_PATH)

# Optionally 
# sample = next(iter(load_dataset("common_voice", "hi", split="test")))
# waveform, sample_rate = torch.tensor(sample["audio"]["array"]), sample["audio"]["sampling_rate"]

# %% [markdown]
# Resample audio to 16Khz

# %%
resampled_audio = torchaudio.functional.resample(waveform, sample_rate, TARGET_SAMPLE_RATE)

# %% [markdown]
# #### Visualize Sample

# %%
display(Audio(resampled_audio.numpy(), rate=TARGET_SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Run Inference

# %% [markdown]
# Load Models from HuggingFace Hub

# %%
# Specify the Hugging Face Model Id 
MODEL_ID = "/home/speech/fq2hf/indicw2v/indicwav2vec_v1_hindi"

# Specify the Device Id on where to put the model
DEVICE_ID = "cuda" if torch.cuda.is_available() else "cpu"
# DEVICE_ID = "cpu"
model = AutoModelForCTC.from_pretrained(MODEL_ID).to(DEVICE_ID)
processor = AutoProcessor.from_pretrained(MODEL_ID)

# %% [markdown]
# Process Audio Data and Run Forward Pass to obtain Logits

# %%
input_tensor = processor(resampled_audio, return_tensors="pt", sampling_rate=TARGET_SAMPLE_RATE).input_values

# Run forward pass
with torch.no_grad():
    logits = model(input_tensor.to(DEVICE_ID)).logits

# %% [markdown]
# Decode Logits to obtain Final Predictions

# %%
output_str = processor.batch_decode(logits.cpu().numpy()).text
print(f"Prediction: {output_str}")
# Out:
# Prediction: ['चुडाक पकड़ना मुश्किली नहीं नामिल थे']

# %% [markdown]
# ## Training ASR Model

# %% [markdown]
# ### Installation and Setup

# %% [markdown]
# #### Insight: End to End ASR Training/Inference Pipeline.

# %% [markdown]
# ### Data Preparation: Manifest Creation

# %% [markdown]
# ### Conifg Setup: What to change and what to not?

# %% [markdown]
# ### Start Training

# %% [markdown]
# #### Insight: Metrics for Evaluation (WER, CER)

# %% [markdown]
# ### Batch Inference

# %% [markdown]
# ## Improving Performance using Language Model

# %% [markdown]
# ### Installation and Setup

# %% [markdown]
# #### Insight: Greedy vs Beam Search Decoding

# %% [markdown]
# ### Dataset Preparation: Clean Text Corpus and Lexicon

# %% [markdown]
# ### Start Training

# %% [markdown]
# ### Batch Inference

# %% [markdown]
# ### Deploying Models

# %% [markdown]
# ### Export models to HuggingFace Format

# %% [markdown]
# ### Deploy model on HuggingFace Spaces
